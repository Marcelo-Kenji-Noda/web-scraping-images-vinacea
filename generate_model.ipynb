# %%
import pandas as pd

# %%
feats = pd.read_parquet("generated_files/features.parquet")

# %%
occurence_absence = pd.read_parquet("assets/INPUT/occurence_abscence.parquet")[['Latitude','Longitude']].reset_index(drop=True)

# %%
feats = feats.merge(occurence_absence.reset_index(), left_index=True, right_index=True)
# Out:
#         BIOVAR1    BIOVAR2    BIOVAR3     BIOVAR4    BIOVAR5  BIOVAR6  \
# 0     23.445833  12.708333  68.693695  199.515991  30.900000     12.4
# 1     23.779167  12.108334  69.588127  162.263245  31.000000     13.6
# 2     23.187500  12.825001  68.951614  190.168869  30.799999     12.2
# 3     23.000000  12.683333  68.931160  183.414581  30.600000     12.2
# 4     23.054167  12.558333  69.001831  170.859589  30.700001     12.5
# ...         ...        ...        ...         ...        ...      ...
# 4342  13.616667  11.733333  50.574711  321.787170  24.700001      1.5
# 4343  14.954166   9.558333  52.808472  313.488129  24.100000      6.0
# 4344  17.020834  10.941667  54.983250  337.392792  26.799999      6.9
# 4345  15.508333   8.416666  50.099205  305.709534  24.000000      7.2
# 4346  15.508333   8.416666  50.099205  305.709534  24.000000      7.2
#
#         BIOVAR7    BIOVAR8    BIOVAR9   BIOVAR10  ...  \
# 0     18.500000  25.100000  20.766666  25.100000  ...
# ...
